# %%
# import

from tqdm import tqdm_notebook  # 진행과정 시각화
from datetime import timedelta  # 시간날짜
import time
import re
import os
import datetime
import pandas as pd
import numpy as np
import gc

import requests
import urllib.request
import urllib.error
import urllib.parse
from bs4 import BeautifulSoup  # 크롤링

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options

from IPython.core.display import display, HTML
display(HTML('<style>.container {width:100% !important; }</style>'))
# Out:
# <style>.container {width:100% !important; }</style>

# %%
def del_outword(string):
    '''크롤링 후 이모티콘, \u200b과 같은 문자가 아닌 것 제거
    [출처](https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python)
    '''
    #이모지제거
    emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
    "]+", flags=re.UNICODE)

    #분석에 어긋나는 불용어구 제외 (특수문자, 의성어)
    han = re.compile(r'[ㄱ-ㅎㅏ-ㅣ!?~"^_\n\r#\ufeff\u200d\u200b\u7643\ufffd\u682e\u62c4]+')
    
    string = emoji_pattern.sub(r'',string)
    string = han.sub(r'',string)
    
    return string

def time_change(x):
    '''검색결과에 있는 문자를 날짜로 변경
    네이버 블로그 크롤링시 작성일자가 1분전/1시간전/1일전으로 나타는 경우가 가끔씩 존재
    이러한 패턴을 일반적인 YY-MM-DD형태로 변환함
    그리고 월별 계산이 중요하므로 모든 데이터는 1일로 통일
    
    Return
    -------
    x : datetime
        날짜형형태로 전환
        
    Example
    -------
    >>> x = "47분 전"
    >>> time_change(x)
    datetime.datetime(2020, 6, 1, 0, 0)
    
    >>> x2 = "2019.01.31"
    >>> time_change(x2)
    datetime.datetime(2019, 1, 1, 0, 0)
    '''
    
    min_pattern = re.compile('[0-9]+'+"분 전")
    hour_pattern = re.compile('[0-9]+'+"시간 전")
    day_pattern = re.compile('[0-9]+'+"일 전")

    today = datetime.datetime.today().date()
    # 일자
    if "일" in x :
        d = re.findall(day_pattern, x)[0][0]
        x = today - timedelta(days=int(d))
    elif "시간" in x:
        d = re.findall(hour_pattern, x)[0]
        x = today
    elif "분" in x:
        d = re.findall(min_pattern, x)[0]
        x = today
    elif x == "어제":
        x = today - timedelta(days=1)
    elif type(x) == str: # 'YY.NN.DD'형태
        x = datetime.datetime.strptime(x.replace('.', '-')[:-1], '%Y-%m-%d')
    
    #모든일자를 1일로 통일
    x = datetime.datetime.strptime(x.strftime('%Y-%m')+"-01","%Y-%m-%d")
    return x

def make_date_list(start_year,end_year,month_gap = 1,year_gap = 1, types = 'month'):
    '''검색에 사용할 날짜 list를 생성
    시작년도, 마지막년도를 입력하고 월별간격, 연별 간격을 입력하면
    검색에 사용할 "YYMMDD"형태의 날짜 list를 반환
    
    Parameters
    ----------
    start_year(int) : 검색을 시작할 연도
    end_year(int) : 검색을 종료할 연도
    month_gap(int) : 몇개월 단위로 검색할 것인지
    year_gap(int) : 몇년 단위로 검색할 것인지
    types(string) : 'year' or 'month'로 연간검색 혹은 월간검색지정
    
    Returns 
    -------
    start_date, end_date : list
        YYMMDD형태의 string형태의 날짜들은 반환한다
    
    Examples
    --------
    >>> make_date_list(start_year = 2010, end_year = 2011,month_gap = 1,year_gap = 1, types = 'month')
    start_date = ['20100101', '20100701', '20110101', '20110701']
    end_date = ['20100131', '20100731', '20110131', '20110731']
    
    >>> make_date_list(start_year = 2010, end_year = 2013,year_gap = 1, types = 'year')
    start_date = ['20100101', '20110101', '20120101', '20130101']
    end_date = ['20101231', '20111231', '20121231', '20131231']
    '''
    #일자
    month_gap = month_gap*100
    start_month = []
    end_month = []
    
    #MMDD 형태 추출
    for date in range(101,1202,month_gap):
        start_month.append(date)
    start_month = list(map(lambda x : '{:0>4}'.format(str(x)),start_month))

    for date in range(131,1232,month_gap):
        end_month.append(date)
    end_month = list(map(lambda x : '{:0>4}'.format(str(x)),end_month))

    start_date = []
    end_date = []
    
    #YYMMDD 형태로 추출
    if types.lower() == 'month':
        for year in range(start_year,end_year+1,year_gap):
            for date in start_month:
                start_date.append(str(year)+date)
            for date in end_month:
                end_date.append(str(year)+date)
    elif types.lower() == 'year':
        for year in range(start_year,end_year+1,year_gap):
            start_date.append(str(year)+'0101')
            end_date.append(str(year)+'1231')
            
        
    return start_date,end_date

# %%
def make_date_list(start_year,end_year,month_gap = 1,year_gap = 1, types = 'month'):
    '''검색에 사용할 날짜 list를 생성
    시작년도, 마지막년도를 입력하고 월별간격, 연별 간격을 입력하면
    검색에 사용할 "YYMMDD"형태의 날짜 list를 반환
    
    Parameters
    ----------
    start_year(int) : 검색을 시작할 연도
    end_year(int) : 검색을 종료할 연도
    month_gap(int) : 몇개월 단위로 검색할 것인지
    year_gap(int) : 몇년 단위로 검색할 것인지
    types(string) : 'year' or 'month'로 연간검색 혹은 월간검색지정
    
    Returns 
    -------
    start_date, end_date : list
        YYMMDD형태의 string형태의 날짜들은 반환한다
    
    Examples
    --------
    >>> make_date_list(start_year = 2010, end_year = 2011,month_gap = 1,year_gap = 1, types = 'month')
    start_date = ['20100101', '20100701', '20110101', '20110701']
    end_date = ['20100131', '20100731', '20110131', '20110731']
    
    >>> make_date_list(start_year = 2010, end_year = 2013,year_gap = 1, types = 'year')
    start_date = ['20100101', '20110101', '20120101', '20130101']
    end_date = ['20101231', '20111231', '20121231', '20131231']
    '''
    #일자
    month_gap = month_gap*100
    start_month = []
    end_month = []
    
    #MMDD 형태 추출
    for date in range(101,1202,month_gap):
        start_month.append(date)
    start_month = list(map(lambda x : '{:0>4}'.format(str(x)),start_month))

    for date in range(131,1232,month_gap):
        end_month.append(date)
    end_month = list(map(lambda x : '{:0>4}'.format(str(x)),end_month))

    start_date = []
    end_date = []
    
    #YYMMDD 형태로 추출
    if types.lower() == 'month':
        for year in range(start_year,end_year+1,year_gap):
            for date in start_month:
                start_date.append(str(year)+date)
            for date in end_month:
                end_date.append(str(year)+date)
    elif types.lower() == 'year':
        for year in range(start_year,end_year+1,year_gap):
            start_date.append(str(year)+'0101')
            end_date.append(str(year)+'1231')
            
        
    return start_date,end_date

# %%
keyword = '강릉'
date_option=8
date_from='20200101'
date_to='20201231'
base_url = f'https://search.naver.com/search.naver?date_from={date_from}&date_option={date_option}&date_to={date_to}&dup_remove=1&nso=&post_blogurl=&post_blogurl_without=&query={keyword}&sm=tab_pge&srchby=all&st=sim&where=post'
#저장위치
os.makedirs('./new_output',exist_ok=True)

# %% [markdown]
# ### 함수화
# * 추가스크롤 발생시 추가로 url복사됨 (현재해결방안 중복된것 drop) -> 추후 특정위치 이상 발전이 없으면 중지하는 방안 필요

# %%
def new_crawling(keyword, date_from='', date_to='', save=True):
    '''네이버 블로그 검색결과가 드래그 방식으로 바뀜(기존 페이지방식)
    따라서 셀레니움으로 최대(1000건) 드래그후 작성일자, 제목, url을 가져온 후 
    request로 각 블로그에 접속하여 본문추출
    이 과정에서 네이버블로그가 아닌 블로그 제외됨(tistory, daum등)
    
    parameter
    ---------
    keyword(string) : 검색하고 싶은 키워드 "keyword +필수어" 형태로 필수단어 추가 가능
    date_from(YYYYMMDD) : (default = "") date_option이 8일때 사용 검색 시작일자를 지정
    date_to(YYYYMMDD) : (default = ""), date_option이 8일때 사용 검색 마지막일자를 지정
    save(bool) : (default = True)csv로 저장 여부 결정
    
    Returns
    ---------
    df : DataFrame
      post_dates title  full_text         url
    0 2010-01-01 title  [full_text]       http://blog.naver.com/PostView.nhn?blogId=wend...  
    
    '''
    
    base_url = f'https://search.naver.com/search.naver?date_from={date_from}&date_option=8&date_to={date_to}&dup_remove=1&nso=&post_blogurl=&post_blogurl_without=&query={keyword}&sm=tab_pge&srchby=all&st=sim&where=post'
    
    #임시저장
    blog_urls = dict()
    blog_urls['dates'] = []
    blog_urls['title'] = []
    blog_urls['urls'] = []
    options = Options()
    
    # 크롬드라이버 작동 
    options.add_argument('--start-maximized') #전체화면
    options.add_argument('--headless') #headless(화면안켜고)
    driver = webdriver.Chrome(executable_path='./chromedriver', chrome_options=options)
    driver.get(base_url)

    #최대 아래로 스크롤
    count =1
    string = '1'
    some_tag = '1'
    for i in range(0,40):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.5)
        count += 1
    source = driver.page_source
    # print(count)
    driver.close()

    #각 정보 불러오기
    soup = BeautifulSoup(source, 'html.parser')

    #dates
    dates_list = soup.select('div > div.total_sub > span > span > span.etc_dsc_area > span')
    dates = pd.Series(dates_list).apply(lambda x : x.text)
    blog_urls['dates'] = blog_urls['dates'] + list(dates)

    #titles
    title_list = soup.select('div > a.api_txt_lines.total_tit')
    titles = pd.Series(title_list).apply(lambda x : x.text)
    blog_urls['title'] = blog_urls['title'] + list(titles)

    #link
    link_list = soup.select('div.total_dsc_wrap a.total_dsc')
    links = pd.Series(link_list).apply(lambda x : x.get('href'))
    blog_urls['urls'] = blog_urls['urls'] + list(links)
    
    #중복제거
    df = pd.DataFrame(blog_urls)
    df = df.drop_duplicates('urls')
    blog_urls['urls'] = df['urls']
    ori_length = len(blog_urls['urls'])
    # 본문가져오기
    output_error = []
    texts = []
    for i, url in tqdm_notebook(enumerate(blog_urls['urls'])):
        count = i
        try:
            # 블로그 url안에 들어가기(아직 크롤링불가)
            get_blog_post_content_code = requests.get(url)
            get_blog_post_content_text = get_blog_post_content_code.text
            get_blog_post_content_soup = BeautifulSoup(
                get_blog_post_content_text, 'lxml')

            # 크롤링가능한 url에 접속
            real_blog_post_url = "http://blog.naver.com" + get_blog_post_content_soup.select('#mainFrame')[0].get('src')
            get_real_blog_post_content_code = requests.get(real_blog_post_url)
            get_real_blog_post_content_text = get_real_blog_post_content_code.text
            get_real_blog_post_content_soup = BeautifulSoup(get_real_blog_post_content_text, 'lxml')

            # 본문  (postviewarea 패턴과 se-main-container 2가지 유형이 있어 분리함)
            try:
                blog_post_content = get_real_blog_post_content_soup.select('div.se-main-container')
                if len(blog_post_content) == 0:
                    blog_post_content = get_real_blog_post_content_soup.select('div#postViewArea')
                    if len(blog_post_content) == 0:
                        blog_post_content = get_real_blog_post_content_soup.select('div.se_component_wrap.sect_dsc.__se_component_area')

                string = ""
                for sentence in blog_post_content[0].stripped_strings:
                    try :
                        string += " "+sentence.replace('\xa0', " ")
                    except :
                        pass
                    # 비언어 텍스트제거
                string = del_outword(string)
                # 공백에러대처
                blank_check = string.replace(" ", "")
                if len(blank_check) == 0:
                    texts.append(["X"])
                else:
                    texts.append([string])
                count += 1
            except Exception as ex:
                print(ex)
                texts.append(["X"])
                output_error.append(count)
                count += 1

        except Exception as ex:
#             print('가져오기에러 {num}번째'.format(num=count), ex)
            output_error.append(count)
            count += 1
            pass

    #후처리 및 dataframe 생성
    df = df.drop(output_error)
    df['text'] = texts
    lenght = df.shape[0]
    last_length = len(output_error)
    print(f'검색된길이:{ori_length},제외된 길이:{last_length}')

    #저장
    if save == True:
        today = datetime.datetime.today().date()
        str(today)
        os.makedirs(f'./new_output/{keyword}',exist_ok=True)
        df.to_csv(f'./new_output/{keyword}/{date_from}~{date_to}_{keyword}_{last_length}_{today}.csv',index=False)
    return df

# %%
start_dates, end_dates = make_date_list(2010,2011)
for date_num in range(0, len(date_from)):
    date_from = start_dates[date_num]
    date_to = end_dates[date_num]
    new_crawling(keyword, date_from, date_to,True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: use options instead of chrome_options
# 검색된길이: 1000
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:76: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 8번째 list index out of range
# 가져오기에러 31번째 list index out of range
# 가져오기에러 64번째 list index out of range
# 가져오기에러 84번째 list index out of range
# 가져오기에러 86번째 list index out of range
# 가져오기에러 87번째 list index out of range
# 가져오기에러 88번째 list index out of range
# 가져오기에러 96번째 list index out of range
# 가져오기에러 103번째 list index out of range
# 가져오기에러 104번째 list index out of range
# 가져오기에러 105번째 list index out of range
# 가져오기에러 114번째 list index out of range
# 가져오기에러 115번째 list index out of range
# 가져오기에러 117번째 list index out of range
# 가져오기에러 121번째 list index out of range
# 가져오기에러 124번째 list index out of range
# 가져오기에러 126번째 list index out of range
# 가져오기에러 131번째 list index out of range
# 가져오기에러 133번째 list index out of range
# 가져오기에러 137번째 list index out of range
# 가져오기에러 138번째 list index out of range
# 가져오기에러 144번째 list index out of range
# 가져오기에러 146번째 list index out of range
# 가져오기에러 184번째 list index out of range
# 가져오기에러 186번째 list index out of range
# 가져오기에러 197번째 list index out of range
# 가져오기에러 202번째 list index out of range
# 가져오기에러 203번째 list index out of range
# 가져오기에러 206번째 list index out of range
# 가져오기에러 209번째 list index out of range
# 가져오기에러 214번째 list index out of range
# 가져오기에러 218번째 list index out of range
# 가져오기에러 220번째 list index out of range
# 가져오기에러 226번째 list index out of range
# 가져오기에러 228번째 list index out of range
# 가져오기에러 231번째 list index out of range
# 가져오기에러 234번째 list index out of range
# 가져오기에러 235번째 list index out of range
# 가져오기에러 237번째 list index out of range
# 가져오기에러 238번째 list index out of range
# 가져오기에러 244번째 list index out of range
# 가져오기에러 251번째 list index out of range
# 가져오기에러 253번째 list index out of range
# 가져오기에러 254번째 list index out of range
# 가져오기에러 258번째 list index out of range
# 가져오기에러 260번째 list index out of range
# 가져오기에러 265번째 list index out of range
# 가져오기에러 267번째 list index out of range
# 가져오기에러 268번째 list index out of range
# 가져오기에러 269번째 list index out of range
# 가져오기에러 275번째 list index out of range
# 가져오기에러 276번째 list index out of range
# 가져오기에러 278번째 list index out of range
# 가져오기에러 280번째 list index out of range
# 가져오기에러 281번째 list index out of range
# 가져오기에러 283번째 list index out of range
# 가져오기에러 287번째 list index out of range
# 가져오기에러 289번째 list index out of range
# 가져오기에러 291번째 list index out of range
# 가져오기에러 293번째 list index out of range
# 가져오기에러 294번째 list index out of range
# 가져오기에러 296번째 list index out of range
# 가져오기에러 300번째 list index out of range
# 가져오기에러 309번째 list index out of range
# 가져오기에러 310번째 list index out of range
# 가져오기에러 311번째 list index out of range
# 가져오기에러 312번째 list index out of range
# 가져오기에러 315번째 list index out of range
# 가져오기에러 317번째 list index out of range
# 가져오기에러 327번째 list index out of range
# 가져오기에러 343번째 list index out of range
# 가져오기에러 345번째 list index out of range
# 가져오기에러 347번째 list index out of range
# 가져오기에러 350번째 list index out of range
# 가져오기에러 368번째 list index out of range
# 가져오기에러 373번째 list index out of range
# 가져오기에러 375번째 list index out of range
# 가져오기에러 397번째 list index out of range
# 가져오기에러 404번째 list index out of range
# 가져오기에러 444번째 list index out of range
# 가져오기에러 445번째 list index out of range
# 가져오기에러 446번째 list index out of range
# 가져오기에러 449번째 list index out of range
# 가져오기에러 450번째 list index out of range
# 가져오기에러 455번째 list index out of range
# 가져오기에러 461번째 list index out of range
# 가져오기에러 476번째 list index out of range
# 가져오기에러 480번째 list index out of range
# 가져오기에러 481번째 list index out of range
# 가져오기에러 493번째 list index out of range
# 가져오기에러 501번째 list index out of range
# 가져오기에러 502번째 list index out of range
# 가져오기에러 503번째 list index out of range
# 가져오기에러 504번째 list index out of range
# 가져오기에러 505번째 list index out of range
# 가져오기에러 506번째 list index out of range
# 가져오기에러 510번째 list index out of range
# 가져오기에러 513번째 list index out of range
# 가져오기에러 516번째 list index out of range
# 가져오기에러 519번째 list index out of range
# 가져오기에러 525번째 list index out of range
# 가져오기에러 530번째 list index out of range
# 가져오기에러 538번째 list index out of range
# 가져오기에러 539번째 list index out of range
# 가져오기에러 543번째 list index out of range
# 가져오기에러 552번째 list index out of range
# 가져오기에러 555번째 list index out of range
# 가져오기에러 560번째 list index out of range
# 가져오기에러 569번째 list index out of range
# 가져오기에러 573번째 list index out of range
# 가져오기에러 578번째 list index out of range
# 가져오기에러 591번째 list index out of range
# 가져오기에러 596번째 list index out of range
# 가져오기에러 622번째 list index out of range
# 가져오기에러 629번째 list index out of range
# 가져오기에러 651번째 list index out of range
# 가져오기에러 666번째 list index out of range
# 가져오기에러 671번째 list index out of range
# 가져오기에러 677번째 list index out of range
# 가져오기에러 678번째 list index out of range
# 가져오기에러 689번째 list index out of range
# 가져오기에러 702번째 list index out of range
# 가져오기에러 710번째 list index out of range
# 가져오기에러 711번째 list index out of range
# 가져오기에러 713번째 list index out of range
# 가져오기에러 716번째 list index out of range
# 가져오기에러 717번째 list index out of range
# 가져오기에러 721번째 list index out of range
# 가져오기에러 729번째 list index out of range
# 가져오기에러 735번째 list index out of range
# 가져오기에러 794번째 list index out of range
# 가져오기에러 798번째 list index out of range
# 가져오기에러 799번째 list index out of range
# 가져오기에러 814번째 list index out of range
# 가져오기에러 826번째 list index out of range
# 가져오기에러 838번째 list index out of range
# 가져오기에러 844번째 list index out of range
# 가져오기에러 848번째 list index out of range
# 가져오기에러 860번째 list index out of range
# 가져오기에러 866번째 list index out of range
# 가져오기에러 871번째 list index out of range
# 가져오기에러 877번째 list index out of range
# 가져오기에러 880번째 list index out of range
# 가져오기에러 884번째 list index out of range
# 가져오기에러 886번째 list index out of range
# 가져오기에러 888번째 list index out of range
# 가져오기에러 891번째 list index out of range
# 가져오기에러 896번째 list index out of range
# 가져오기에러 899번째 list index out of range
# 가져오기에러 900번째 list index out of range
# 가져오기에러 902번째 list index out of range
# 가져오기에러 905번째 list index out of range
# 가져오기에러 906번째 list index out of range
# 가져오기에러 908번째 list index out of range
# 가져오기에러 909번째 list index out of range
# 가져오기에러 911번째 list index out of range
# 가져오기에러 913번째 list index out of range
# 가져오기에러 917번째 list index out of range
# 가져오기에러 925번째 list index out of range
# 가져오기에러 929번째 list index out of range
# 가져오기에러 930번째 list index out of range
# 가져오기에러 931번째 list index out of range
# 가져오기에러 937번째 list index out of range
# 가져오기에러 943번째 list index out of range
# 가져오기에러 947번째 list index out of range
# 가져오기에러 957번째 list index out of range
# 가져오기에러 964번째 list index out of range
# 가져오기에러 965번째 list index out of range
# 가져오기에러 966번째 list index out of range
# 가져오기에러 967번째 list index out of range
# 가져오기에러 973번째 list index out of range
# 가져오기에러 974번째 list index out of range
# 가져오기에러 979번째 list index out of range
# 가져오기에러 981번째 list index out of range
# 가져오기에러 982번째 list index out of range
# 가져오기에러 983번째 list index out of range
# 가져오기에러 985번째 list index out of range
# 가져오기에러 987번째 list index out of range
# 가져오기에러 990번째 list index out of range
# 가져오기에러 992번째 list index out of range
# 가져오기에러 993번째 list index out of range
# 가져오기에러 996번째 list index out of range
#
# 검색된길이: 1000
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 5번째 list index out of range
# 가져오기에러 8번째 list index out of range
# 가져오기에러 14번째 list index out of range
# 가져오기에러 17번째 list index out of range
# 가져오기에러 38번째 list index out of range
# 가져오기에러 47번째 list index out of range
# 가져오기에러 49번째 list index out of range
# 가져오기에러 64번째 list index out of range
# 가져오기에러 71번째 list index out of range
# 가져오기에러 75번째 list index out of range
# 가져오기에러 96번째 list index out of range
# 가져오기에러 97번째 list index out of range
# 가져오기에러 104번째 list index out of range
# 가져오기에러 106번째 list index out of range
# 가져오기에러 110번째 list index out of range
# 가져오기에러 111번째 list index out of range
# 가져오기에러 114번째 list index out of range
# 가져오기에러 116번째 list index out of range
# 가져오기에러 118번째 list index out of range
# 가져오기에러 126번째 list index out of range
# 가져오기에러 129번째 list index out of range
# 가져오기에러 134번째 list index out of range
# 가져오기에러 137번째 list index out of range
# 가져오기에러 141번째 list index out of range
# 가져오기에러 143번째 list index out of range
# 가져오기에러 171번째 list index out of range
# 가져오기에러 188번째 list index out of range
# 가져오기에러 200번째 list index out of range
# 가져오기에러 202번째 list index out of range
# 가져오기에러 206번째 list index out of range
# 가져오기에러 208번째 list index out of range
# 가져오기에러 210번째 list index out of range
# 가져오기에러 213번째 list index out of range
# 가져오기에러 223번째 list index out of range
# 가져오기에러 224번째 list index out of range
# 가져오기에러 227번째 list index out of range
# 가져오기에러 228번째 list index out of range
# 가져오기에러 231번째 list index out of range
# 가져오기에러 233번째 list index out of range
# 가져오기에러 235번째 list index out of range
# 가져오기에러 237번째 list index out of range
# 가져오기에러 242번째 list index out of range
# 가져오기에러 244번째 list index out of range
# 가져오기에러 245번째 list index out of range
# 가져오기에러 248번째 list index out of range
# 가져오기에러 256번째 list index out of range
# 가져오기에러 259번째 list index out of range
# 가져오기에러 264번째 list index out of range
# 가져오기에러 265번째 list index out of range
# 가져오기에러 272번째 list index out of range
# 가져오기에러 277번째 list index out of range
# 가져오기에러 279번째 list index out of range
# 가져오기에러 281번째 list index out of range
# 가져오기에러 282번째 list index out of range
# 가져오기에러 285번째 list index out of range
# 가져오기에러 287번째 list index out of range
# 가져오기에러 288번째 list index out of range
# 가져오기에러 290번째 list index out of range
# 가져오기에러 298번째 list index out of range
# 가져오기에러 299번째 list index out of range
# 가져오기에러 301번째 list index out of range
# 가져오기에러 306번째 list index out of range
# 가져오기에러 314번째 list index out of range
# 가져오기에러 315번째 list index out of range
# 가져오기에러 316번째 list index out of range
# 가져오기에러 317번째 list index out of range
# 가져오기에러 318번째 list index out of range
# 가져오기에러 319번째 list index out of range
# 가져오기에러 320번째 list index out of range
# 가져오기에러 325번째 list index out of range
# 가져오기에러 329번째 list index out of range
# 가져오기에러 335번째 list index out of range
# 가져오기에러 337번째 list index out of range
# 가져오기에러 340번째 list index out of range
# 가져오기에러 346번째 list index out of range
# 가져오기에러 350번째 list index out of range
# 가져오기에러 352번째 list index out of range
# 가져오기에러 358번째 list index out of range
# 가져오기에러 359번째 list index out of range
# 가져오기에러 360번째 list index out of range
# 가져오기에러 363번째 list index out of range
# 가져오기에러 364번째 list index out of range
# 가져오기에러 384번째 list index out of range
# 가져오기에러 386번째 list index out of range
# 가져오기에러 389번째 list index out of range
# 가져오기에러 394번째 list index out of range
# 가져오기에러 398번째 list index out of range
# 가져오기에러 404번째 list index out of range
# 가져오기에러 406번째 list index out of range
# 가져오기에러 407번째 list index out of range
# 가져오기에러 412번째 list index out of range
# 가져오기에러 416번째 list index out of range
# 가져오기에러 417번째 list index out of range
# 가져오기에러 418번째 list index out of range
# 가져오기에러 419번째 list index out of range
# 가져오기에러 420번째 list index out of range
# 가져오기에러 421번째 list index out of range
# 가져오기에러 427번째 list index out of range
# 가져오기에러 441번째 list index out of range
# 가져오기에러 445번째 list index out of range
# 가져오기에러 453번째 list index out of range
# 가져오기에러 455번째 list index out of range
# 가져오기에러 497번째 list index out of range
# 가져오기에러 498번째 list index out of range
# 가져오기에러 499번째 list index out of range
# 가져오기에러 501번째 list index out of range
# 가져오기에러 502번째 list index out of range
# 가져오기에러 503번째 list index out of range
# 가져오기에러 504번째 list index out of range
# 가져오기에러 509번째 list index out of range
# 가져오기에러 528번째 list index out of range
# 가져오기에러 529번째 list index out of range
# 가져오기에러 530번째 list index out of range
# 가져오기에러 534번째 list index out of range
# 가져오기에러 554번째 list index out of range
# 가져오기에러 555번째 list index out of range
# 가져오기에러 566번째 list index out of range
# 가져오기에러 569번째 list index out of range
# 가져오기에러 579번째 list index out of range
# 가져오기에러 593번째 list index out of range
# 가져오기에러 597번째 list index out of range
# 가져오기에러 598번째 list index out of range
# 가져오기에러 599번째 list index out of range
# 가져오기에러 602번째 list index out of range
# 가져오기에러 657번째 list index out of range
# 가져오기에러 662번째 list index out of range
# 가져오기에러 670번째 list index out of range
# 가져오기에러 679번째 list index out of range
# 가져오기에러 693번째 list index out of range
# 가져오기에러 706번째 list index out of range
# 가져오기에러 712번째 list index out of range
# 가져오기에러 722번째 list index out of range
# 가져오기에러 729번째 list index out of range
# 가져오기에러 731번째 list index out of range
# 가져오기에러 751번째 list index out of range
# 가져오기에러 754번째 list index out of range
# 가져오기에러 762번째 list index out of range
# 가져오기에러 763번째 list index out of range
# 가져오기에러 764번째 list index out of range
# 가져오기에러 778번째 list index out of range
# 가져오기에러 786번째 list index out of range
# 가져오기에러 788번째 list index out of range
# 가져오기에러 791번째 list index out of range
# 가져오기에러 793번째 list index out of range
# 가져오기에러 796번째 list index out of range
# 가져오기에러 805번째 list index out of range
# 가져오기에러 806번째 list index out of range
# 가져오기에러 808번째 list index out of range
# 가져오기에러 813번째 list index out of range
# 가져오기에러 842번째 list index out of range
# 가져오기에러 846번째 list index out of range
# 가져오기에러 851번째 list index out of range
# 가져오기에러 857번째 list index out of range
# 가져오기에러 863번째 list index out of range
# 가져오기에러 864번째 list index out of range
# 가져오기에러 871번째 list index out of range
# 가져오기에러 876번째 list index out of range
# 가져오기에러 894번째 list index out of range
# 가져오기에러 896번째 list index out of range
# 가져오기에러 900번째 list index out of range
# 가져오기에러 902번째 list index out of range
# 가져오기에러 906번째 list index out of range
# 가져오기에러 913번째 list index out of range
# 가져오기에러 920번째 list index out of range
# 가져오기에러 922번째 list index out of range
# 가져오기에러 926번째 list index out of range
# 가져오기에러 927번째 list index out of range
# 가져오기에러 928번째 list index out of range
# 가져오기에러 929번째 list index out of range
# 가져오기에러 936번째 list index out of range
# 가져오기에러 937번째 list index out of range
# 가져오기에러 940번째 list index out of range
# 가져오기에러 944번째 list index out of range
# 가져오기에러 953번째 list index out of range
# 가져오기에러 956번째 list index out of range
# 가져오기에러 962번째 list index out of range
# 가져오기에러 964번째 list index out of range
# 가져오기에러 973번째 list index out of range
# 가져오기에러 975번째 list index out of range
# 가져오기에러 980번째 list index out of range
# 가져오기에러 982번째 list index out of range
# 가져오기에러 987번째 list index out of range
# 가져오기에러 990번째 list index out of range
# 가져오기에러 993번째 list index out of range
# 가져오기에러 995번째 list index out of range
#
# 검색된길이: 1000
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 12번째 list index out of range
# 가져오기에러 34번째 list index out of range
# 가져오기에러 53번째 list index out of range
# 가져오기에러 71번째 list index out of range
# 가져오기에러 79번째 list index out of range
# 가져오기에러 82번째 list index out of range
# 가져오기에러 87번째 list index out of range
# 가져오기에러 88번째 list index out of range
# 가져오기에러 90번째 list index out of range
# 가져오기에러 95번째 list index out of range
# 가져오기에러 96번째 list index out of range
# 가져오기에러 97번째 list index out of range
# 가져오기에러 99번째 list index out of range
# 가져오기에러 101번째 list index out of range
# 가져오기에러 104번째 list index out of range
# 가져오기에러 110번째 list index out of range
# 가져오기에러 124번째 list index out of range
# 가져오기에러 144번째 list index out of range
# 가져오기에러 147번째 list index out of range
# 가져오기에러 152번째 list index out of range
# 가져오기에러 153번째 list index out of range
# 가져오기에러 155번째 list index out of range
# 가져오기에러 164번째 list index out of range
# 가져오기에러 171번째 list index out of range
# 가져오기에러 172번째 list index out of range
# 가져오기에러 177번째 list index out of range
# 가져오기에러 179번째 list index out of range
# 가져오기에러 183번째 list index out of range
# 가져오기에러 191번째 list index out of range
# 가져오기에러 192번째 list index out of range
# 가져오기에러 208번째 list index out of range
# 가져오기에러 211번째 list index out of range
# 가져오기에러 216번째 list index out of range
# 가져오기에러 220번째 list index out of range
# 가져오기에러 227번째 list index out of range
# 가져오기에러 228번째 list index out of range
# 가져오기에러 231번째 list index out of range
# 가져오기에러 232번째 list index out of range
# 가져오기에러 233번째 list index out of range
# 가져오기에러 246번째 list index out of range
# 가져오기에러 250번째 list index out of range
# 가져오기에러 256번째 list index out of range
# 가져오기에러 258번째 list index out of range
# 가져오기에러 260번째 list index out of range
# 가져오기에러 269번째 list index out of range
# 가져오기에러 270번째 list index out of range
# 가져오기에러 274번째 list index out of range
# 가져오기에러 276번째 list index out of range
# 가져오기에러 281번째 list index out of range
# 가져오기에러 282번째 list index out of range
# 가져오기에러 283번째 list index out of range
# 가져오기에러 284번째 list index out of range
# 가져오기에러 286번째 list index out of range
# 가져오기에러 293번째 list index out of range
# 가져오기에러 318번째 list index out of range
# 가져오기에러 345번째 list index out of range
# 가져오기에러 355번째 list index out of range
# 가져오기에러 356번째 list index out of range
# 가져오기에러 359번째 list index out of range
# 가져오기에러 361번째 list index out of range
# 가져오기에러 366번째 list index out of range
# 가져오기에러 367번째 list index out of range
# 가져오기에러 369번째 list index out of range
# 가져오기에러 370번째 list index out of range
# 가져오기에러 375번째 list index out of range
# 가져오기에러 383번째 list index out of range
# 가져오기에러 469번째 list index out of range
# 가져오기에러 470번째 list index out of range
# 가져오기에러 474번째 list index out of range
# 가져오기에러 476번째 list index out of range
# 가져오기에러 477번째 list index out of range
# 가져오기에러 480번째 list index out of range
# 가져오기에러 482번째 list index out of range
# 가져오기에러 489번째 list index out of range
# 가져오기에러 490번째 list index out of range
# 가져오기에러 495번째 list index out of range
# 가져오기에러 496번째 list index out of range
# 가져오기에러 499번째 list index out of range
# 가져오기에러 500번째 list index out of range
# 가져오기에러 501번째 list index out of range
# 가져오기에러 502번째 list index out of range
# 가져오기에러 504번째 list index out of range
# 가져오기에러 505번째 list index out of range
# 가져오기에러 517번째 list index out of range
# 가져오기에러 523번째 list index out of range
# 가져오기에러 528번째 list index out of range
# 가져오기에러 535번째 list index out of range
# 가져오기에러 538번째 list index out of range
# 가져오기에러 549번째 list index out of range
# 가져오기에러 550번째 list index out of range
# 가져오기에러 571번째 list index out of range
# 가져오기에러 574번째 list index out of range
# 가져오기에러 596번째 list index out of range
# 가져오기에러 598번째 list index out of range
# 가져오기에러 605번째 list index out of range
# 가져오기에러 608번째 list index out of range
# 가져오기에러 609번째 list index out of range
# 가져오기에러 610번째 list index out of range
# 가져오기에러 631번째 list index out of range
# 가져오기에러 644번째 list index out of range
# 가져오기에러 647번째 list index out of range
# 가져오기에러 656번째 list index out of range
# 가져오기에러 659번째 list index out of range
# 가져오기에러 663번째 list index out of range
# 가져오기에러 673번째 list index out of range
# 가져오기에러 690번째 list index out of range
# 가져오기에러 692번째 list index out of range
# 가져오기에러 725번째 list index out of range
# 가져오기에러 727번째 list index out of range
# 가져오기에러 741번째 list index out of range
# 가져오기에러 745번째 list index out of range
# 가져오기에러 748번째 list index out of range
# 가져오기에러 752번째 list index out of range
# 가져오기에러 757번째 list index out of range
# 가져오기에러 759번째 list index out of range
# 가져오기에러 763번째 list index out of range
# 가져오기에러 764번째 list index out of range
# 가져오기에러 765번째 list index out of range
# 가져오기에러 775번째 list index out of range
# 가져오기에러 784번째 list index out of range
# 가져오기에러 793번째 list index out of range
# 가져오기에러 794번째 list index out of range
# 가져오기에러 807번째 list index out of range
# 가져오기에러 868번째 list index out of range
# 가져오기에러 873번째 list index out of range
# 가져오기에러 876번째 list index out of range
# 가져오기에러 877번째 list index out of range
# 가져오기에러 880번째 list index out of range
# 가져오기에러 882번째 list index out of range
# 가져오기에러 893번째 list index out of range
# 가져오기에러 896번째 list index out of range
# 가져오기에러 897번째 list index out of range
# 가져오기에러 899번째 list index out of range
# 가져오기에러 901번째 list index out of range
# 가져오기에러 902번째 list index out of range
# 가져오기에러 908번째 list index out of range
# 가져오기에러 909번째 list index out of range
# 가져오기에러 910번째 list index out of range
# 가져오기에러 911번째 list index out of range
# 가져오기에러 912번째 list index out of range
# 가져오기에러 916번째 list index out of range
# 가져오기에러 918번째 list index out of range
# 가져오기에러 924번째 list index out of range
# 가져오기에러 927번째 list index out of range
# 가져오기에러 928번째 list index out of range
# 가져오기에러 932번째 list index out of range
# 가져오기에러 935번째 list index out of range
# 가져오기에러 940번째 list index out of range
# 가져오기에러 941번째 list index out of range
# 가져오기에러 942번째 list index out of range
# 가져오기에러 946번째 list index out of range
# 가져오기에러 947번째 list index out of range
# 가져오기에러 948번째 list index out of range
# 가져오기에러 949번째 list index out of range
# 가져오기에러 954번째 list index out of range
# 가져오기에러 960번째 list index out of range
# 가져오기에러 962번째 list index out of range
# 가져오기에러 965번째 list index out of range
# 가져오기에러 966번째 list index out of range
# 가져오기에러 968번째 list index out of range
# 가져오기에러 969번째 list index out of range
# 가져오기에러 973번째 list index out of range
# 가져오기에러 975번째 list index out of range
# 가져오기에러 980번째 list index out of range
# 가져오기에러 982번째 list index out of range
# 가져오기에러 984번째 list index out of range
# 가져오기에러 985번째 list index out of range
# 가져오기에러 986번째 list index out of range
# 가져오기에러 988번째 list index out of range
# 가져오기에러 991번째 list index out of range
# 가져오기에러 992번째 list index out of range
# 가져오기에러 994번째 list index out of range
# 가져오기에러 995번째 list index out of range
# 가져오기에러 996번째 list index out of range
# 가져오기에러 998번째 list index out of range
# 가져오기에러 999번째 list index out of range
#
# 검색된길이: 1000
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 13번째 list index out of range
# 가져오기에러 15번째 list index out of range
# 가져오기에러 18번째 list index out of range
# 가져오기에러 33번째 list index out of range
# 가져오기에러 72번째 list index out of range
# 가져오기에러 77번째 list index out of range
# 가져오기에러 86번째 list index out of range
# 가져오기에러 97번째 list index out of range
# 가져오기에러 101번째 list index out of range
# 가져오기에러 102번째 list index out of range
# 가져오기에러 104번째 list index out of range
# 가져오기에러 105번째 list index out of range
# 가져오기에러 108번째 list index out of range
# 가져오기에러 110번째 list index out of range
# 가져오기에러 115번째 list index out of range
# 가져오기에러 116번째 list index out of range
# 가져오기에러 117번째 list index out of range
# 가져오기에러 121번째 list index out of range
# 가져오기에러 130번째 list index out of range
# 가져오기에러 157번째 list index out of range
# 가져오기에러 175번째 list index out of range
# 가져오기에러 186번째 list index out of range
# 가져오기에러 187번째 list index out of range
# 가져오기에러 189번째 list index out of range
# 가져오기에러 194번째 list index out of range
# 가져오기에러 199번째 list index out of range
# 가져오기에러 201번째 list index out of range
# 가져오기에러 202번째 list index out of range
# 가져오기에러 203번째 list index out of range
# 가져오기에러 205번째 list index out of range
# 가져오기에러 215번째 list index out of range
# 가져오기에러 216번째 list index out of range
# 가져오기에러 218번째 list index out of range
# 가져오기에러 220번째 list index out of range
# 가져오기에러 223번째 list index out of range
# 가져오기에러 224번째 list index out of range
# 가져오기에러 244번째 list index out of range
# 가져오기에러 245번째 list index out of range
# 가져오기에러 255번째 list index out of range
# 가져오기에러 257번째 list index out of range
# 가져오기에러 259번째 list index out of range
# 가져오기에러 263번째 list index out of range
# 가져오기에러 266번째 list index out of range
# 가져오기에러 270번째 list index out of range
# 가져오기에러 271번째 list index out of range
# 가져오기에러 273번째 list index out of range
# 가져오기에러 277번째 list index out of range
# 가져오기에러 280번째 list index out of range
# 가져오기에러 288번째 list index out of range
# 가져오기에러 294번째 list index out of range
# 가져오기에러 295번째 list index out of range
# 가져오기에러 297번째 list index out of range
# 가져오기에러 298번째 list index out of range
# 가져오기에러 301번째 list index out of range
# 가져오기에러 312번째 list index out of range
# 가져오기에러 313번째 list index out of range
# 가져오기에러 315번째 list index out of range
# 가져오기에러 317번째 list index out of range
# 가져오기에러 319번째 list index out of range
# 가져오기에러 320번째 list index out of range
# 가져오기에러 322번째 list index out of range
# 가져오기에러 323번째 list index out of range
# 가져오기에러 324번째 list index out of range
# 가져오기에러 326번째 list index out of range
# 가져오기에러 330번째 list index out of range
# 가져오기에러 331번째 list index out of range
# 가져오기에러 332번째 list index out of range
# 가져오기에러 337번째 list index out of range
# 가져오기에러 338번째 list index out of range
# 가져오기에러 342번째 list index out of range
# 가져오기에러 344번째 list index out of range
# 가져오기에러 345번째 list index out of range
# 가져오기에러 357번째 list index out of range
# 가져오기에러 362번째 list index out of range
# 가져오기에러 363번째 list index out of range
# 가져오기에러 365번째 list index out of range
# 가져오기에러 366번째 list index out of range
# 가져오기에러 382번째 list index out of range
# 가져오기에러 384번째 list index out of range
# 가져오기에러 389번째 list index out of range
# 가져오기에러 415번째 list index out of range
# 가져오기에러 420번째 list index out of range
# 가져오기에러 421번째 list index out of range
# 가져오기에러 422번째 list index out of range
# 가져오기에러 426번째 list index out of range
# 가져오기에러 433번째 list index out of range
# 가져오기에러 444번째 list index out of range
# 가져오기에러 475번째 list index out of range
# 가져오기에러 476번째 list index out of range
# 가져오기에러 477번째 list index out of range
# 가져오기에러 480번째 list index out of range
# 가져오기에러 484번째 list index out of range
# 가져오기에러 485번째 list index out of range
# 가져오기에러 486번째 list index out of range
# 가져오기에러 493번째 list index out of range
# 가져오기에러 494번째 list index out of range
# 가져오기에러 500번째 list index out of range
# 가져오기에러 501번째 list index out of range
# 가져오기에러 505번째 list index out of range
# 가져오기에러 515번째 list index out of range
# 가져오기에러 518번째 list index out of range
# 가져오기에러 519번째 list index out of range
# 가져오기에러 542번째 list index out of range
# 가져오기에러 546번째 list index out of range
# 가져오기에러 547번째 list index out of range
# 가져오기에러 548번째 list index out of range
# 가져오기에러 552번째 list index out of range
# 가져오기에러 556번째 list index out of range
# 가져오기에러 558번째 list index out of range
# 가져오기에러 562번째 list index out of range
# 가져오기에러 563번째 list index out of range
# 가져오기에러 564번째 list index out of range
# 가져오기에러 577번째 list index out of range
# 가져오기에러 582번째 list index out of range
# 가져오기에러 585번째 list index out of range
# 가져오기에러 587번째 list index out of range
# 가져오기에러 589번째 list index out of range
# 가져오기에러 592번째 list index out of range
# 가져오기에러 595번째 list index out of range
# 가져오기에러 597번째 list index out of range
# 가져오기에러 612번째 list index out of range
# 가져오기에러 621번째 list index out of range
# 가져오기에러 626번째 list index out of range
# 가져오기에러 652번째 list index out of range
# 가져오기에러 653번째 list index out of range
# 가져오기에러 659번째 list index out of range
# 가져오기에러 666번째 list index out of range
# 가져오기에러 675번째 list index out of range
# 가져오기에러 687번째 list index out of range
# 가져오기에러 707번째 list index out of range
# 가져오기에러 712번째 list index out of range
# 가져오기에러 731번째 list index out of range
# 가져오기에러 761번째 list index out of range
# 가져오기에러 764번째 list index out of range
# 가져오기에러 766번째 list index out of range
# 가져오기에러 776번째 list index out of range
# 가져오기에러 777번째 list index out of range
# 가져오기에러 780번째 list index out of range
# 가져오기에러 795번째 list index out of range
# 가져오기에러 798번째 list index out of range
# 가져오기에러 811번째 list index out of range
# 가져오기에러 816번째 list index out of range
# 가져오기에러 852번째 list index out of range
# 가져오기에러 861번째 list index out of range
# 가져오기에러 870번째 list index out of range
# 가져오기에러 876번째 list index out of range
# 가져오기에러 880번째 list index out of range
# 가져오기에러 882번째 list index out of range
# 가져오기에러 888번째 list index out of range
# 가져오기에러 891번째 list index out of range
# 가져오기에러 894번째 list index out of range
# 가져오기에러 899번째 list index out of range
# 가져오기에러 905번째 list index out of range
# 가져오기에러 908번째 list index out of range
# 가져오기에러 911번째 list index out of range
# 가져오기에러 912번째 list index out of range
# 가져오기에러 916번째 list index out of range
# 가져오기에러 919번째 list index out of range
# 가져오기에러 926번째 list index out of range
# 가져오기에러 929번째 list index out of range
# 가져오기에러 930번째 list index out of range
# 가져오기에러 934번째 list index out of range
# 가져오기에러 936번째 list index out of range
# 가져오기에러 937번째 list index out of range
# 가져오기에러 938번째 list index out of range
# 가져오기에러 939번째 list index out of range
# 가져오기에러 951번째 list index out of range
# 가져오기에러 956번째 list index out of range
# 가져오기에러 957번째 list index out of range
# 가져오기에러 958번째 list index out of range
# 가져오기에러 960번째 list index out of range
# 가져오기에러 964번째 list index out of range
# 가져오기에러 965번째 list index out of range
# 가져오기에러 966번째 list index out of range
# 가져오기에러 967번째 list index out of range
# 가져오기에러 968번째 list index out of range
# 가져오기에러 970번째 list index out of range
# 가져오기에러 971번째 list index out of range
# 가져오기에러 972번째 list index out of range
# 가져오기에러 973번째 list index out of range
# 가져오기에러 979번째 list index out of range
# 가져오기에러 981번째 list index out of range
# 가져오기에러 983번째 list index out of range
# 가져오기에러 984번째 list index out of range
# 가져오기에러 986번째 list index out of range
# 가져오기에러 987번째 list index out of range
# 가져오기에러 988번째 list index out of range
# 가져오기에러 992번째 list index out of range
# 가져오기에러 993번째 list index out of range
# 가져오기에러 994번째 list index out of range
# 가져오기에러 995번째 list index out of range
# 가져오기에러 998번째 list index out of range
#
# 검색된길이: 1000
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 31번째 list index out of range
# 가져오기에러 44번째 list index out of range
# 가져오기에러 45번째 list index out of range
# 가져오기에러 55번째 list index out of range
# 가져오기에러 65번째 list index out of range
# 가져오기에러 86번째 list index out of range
# 가져오기에러 100번째 list index out of range
# 가져오기에러 119번째 list index out of range
# 가져오기에러 125번째 list index out of range
# 가져오기에러 126번째 list index out of range
# 가져오기에러 127번째 list index out of range
# 가져오기에러 130번째 list index out of range
# 가져오기에러 133번째 list index out of range
# 가져오기에러 148번째 list index out of range
# 가져오기에러 150번째 list index out of range
# 가져오기에러 176번째 list index out of range
# 가져오기에러 197번째 list index out of range
# 가져오기에러 205번째 list index out of range
# 가져오기에러 207번째 list index out of range
# 가져오기에러 209번째 list index out of range
# 가져오기에러 210번째 list index out of range
# 가져오기에러 211번째 list index out of range
# 가져오기에러 217번째 list index out of range
# 가져오기에러 219번째 list index out of range
# 가져오기에러 222번째 list index out of range
# 가져오기에러 223번째 list index out of range
# 가져오기에러 224번째 list index out of range
# 가져오기에러 225번째 list index out of range
# 가져오기에러 226번째 list index out of range
# 가져오기에러 227번째 list index out of range
# 가져오기에러 230번째 list index out of range
# 가져오기에러 231번째 list index out of range
# 가져오기에러 233번째 list index out of range
# 가져오기에러 236번째 list index out of range
# 가져오기에러 237번째 list index out of range
# 가져오기에러 240번째 list index out of range
# 가져오기에러 242번째 list index out of range
# 가져오기에러 243번째 list index out of range
# 가져오기에러 251번째 list index out of range
# 가져오기에러 253번째 list index out of range
# 가져오기에러 258번째 list index out of range
# 가져오기에러 262번째 list index out of range
# 가져오기에러 264번째 list index out of range
# 가져오기에러 271번째 list index out of range
# 가져오기에러 274번째 list index out of range
# 가져오기에러 280번째 list index out of range
# 가져오기에러 282번째 list index out of range
# 가져오기에러 284번째 list index out of range
# 가져오기에러 285번째 list index out of range
# 가져오기에러 294번째 list index out of range
# 가져오기에러 297번째 list index out of range
# 가져오기에러 300번째 list index out of range
# 가져오기에러 301번째 list index out of range
# 가져오기에러 305번째 list index out of range
# 가져오기에러 307번째 list index out of range
# 가져오기에러 310번째 list index out of range
# 가져오기에러 311번째 list index out of range
# 가져오기에러 316번째 list index out of range
# 가져오기에러 320번째 list index out of range
# 가져오기에러 323번째 list index out of range
# 가져오기에러 324번째 list index out of range
# 가져오기에러 325번째 list index out of range
# 가져오기에러 326번째 list index out of range
# 가져오기에러 327번째 list index out of range
# 가져오기에러 332번째 list index out of range
# 가져오기에러 333번째 list index out of range
# 가져오기에러 340번째 list index out of range
# 가져오기에러 341번째 list index out of range
# 가져오기에러 342번째 list index out of range
# 가져오기에러 344번째 list index out of range
# 가져오기에러 345번째 list index out of range
# 가져오기에러 348번째 list index out of range
# 가져오기에러 356번째 list index out of range
# 가져오기에러 357번째 list index out of range
# 가져오기에러 360번째 list index out of range
# 가져오기에러 364번째 list index out of range
# 가져오기에러 368번째 list index out of range
# 가져오기에러 376번째 list index out of range
# 가져오기에러 386번째 list index out of range
# 가져오기에러 393번째 list index out of range
# 가져오기에러 403번째 list index out of range
# 가져오기에러 406번째 list index out of range
# 가져오기에러 423번째 list index out of range
# 가져오기에러 430번째 list index out of range
# 가져오기에러 431번째 list index out of range
# 가져오기에러 451번째 list index out of range
# 가져오기에러 453번째 list index out of range
# 가져오기에러 454번째 list index out of range
# 가져오기에러 470번째 list index out of range
# 가져오기에러 472번째 list index out of range
# 가져오기에러 473번째 list index out of range
# 가져오기에러 481번째 list index out of range
# 가져오기에러 501번째 list index out of range
# 가져오기에러 504번째 list index out of range
# 가져오기에러 554번째 list index out of range
# 가져오기에러 558번째 list index out of range
# 가져오기에러 559번째 list index out of range
# 가져오기에러 562번째 list index out of range
# 가져오기에러 565번째 list index out of range
# 가져오기에러 576번째 list index out of range
# 가져오기에러 587번째 list index out of range
# 가져오기에러 589번째 list index out of range
# 가져오기에러 590번째 list index out of range
# 가져오기에러 594번째 list index out of range
# 가져오기에러 609번째 list index out of range
# 가져오기에러 610번째 list index out of range
# 가져오기에러 616번째 list index out of range
# 가져오기에러 621번째 list index out of range
# 가져오기에러 624번째 list index out of range
# 가져오기에러 632번째 list index out of range
# 가져오기에러 634번째 list index out of range
# 가져오기에러 641번째 list index out of range
# 가져오기에러 642번째 list index out of range
# 가져오기에러 644번째 list index out of range
# 가져오기에러 649번째 list index out of range
# 가져오기에러 651번째 list index out of range
# 가져오기에러 656번째 list index out of range
# 가져오기에러 657번째 list index out of range
# 가져오기에러 661번째 list index out of range
# 가져오기에러 671번째 list index out of range
# 가져오기에러 677번째 list index out of range
# 가져오기에러 685번째 list index out of range
# 가져오기에러 696번째 list index out of range
# 가져오기에러 700번째 list index out of range
# 가져오기에러 707번째 list index out of range
# 가져오기에러 727번째 list index out of range
# 가져오기에러 731번째 list index out of range
# 가져오기에러 732번째 list index out of range
# 가져오기에러 748번째 list index out of range
# 가져오기에러 756번째 list index out of range
# 가져오기에러 773번째 list index out of range
# 가져오기에러 779번째 list index out of range
# 가져오기에러 796번째 list index out of range
# 가져오기에러 810번째 list index out of range
# 가져오기에러 814번째 list index out of range
# 가져오기에러 816번째 list index out of range
# 가져오기에러 827번째 list index out of range
# 가져오기에러 857번째 list index out of range
# 가져오기에러 860번째 list index out of range
# 가져오기에러 862번째 list index out of range
# 가져오기에러 881번째 list index out of range
# 가져오기에러 885번째 list index out of range
# 가져오기에러 904번째 list index out of range
# 가져오기에러 909번째 list index out of range
# 가져오기에러 924번째 list index out of range
# 가져오기에러 944번째 list index out of range
# 가져오기에러 956번째 list index out of range
# 가져오기에러 965번째 list index out of range
# 가져오기에러 969번째 list index out of range
# 가져오기에러 985번째 list index out of range
# 가져오기에러 990번째 list index out of range
# 가져오기에러 994번째 list index out of range
#
# 검색된길이: 900
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 7번째 list index out of range
# 가져오기에러 15번째 list index out of range
# 가져오기에러 23번째 list index out of range
# 가져오기에러 33번째 list index out of range
# 가져오기에러 46번째 list index out of range
# 가져오기에러 59번째 list index out of range
# 가져오기에러 90번째 list index out of range
# 가져오기에러 92번째 list index out of range
# 가져오기에러 97번째 list index out of range
# 가져오기에러 106번째 list index out of range
# 가져오기에러 110번째 list index out of range
# 가져오기에러 114번째 list index out of range
# 가져오기에러 118번째 list index out of range
# 가져오기에러 122번째 list index out of range
# 가져오기에러 137번째 list index out of range
# 가져오기에러 140번째 list index out of range
# 가져오기에러 143번째 list index out of range
# 가져오기에러 145번째 list index out of range
# 가져오기에러 151번째 list index out of range
# 가져오기에러 154번째 list index out of range
# 가져오기에러 158번째 list index out of range
# 가져오기에러 160번째 list index out of range
# 가져오기에러 161번째 list index out of range
# 가져오기에러 164번째 list index out of range
# 가져오기에러 166번째 list index out of range
# 가져오기에러 169번째 list index out of range
# 가져오기에러 171번째 list index out of range
# 가져오기에러 174번째 list index out of range
# 가져오기에러 175번째 list index out of range
# 가져오기에러 182번째 list index out of range
# 가져오기에러 186번째 list index out of range
# 가져오기에러 190번째 list index out of range
# 가져오기에러 198번째 list index out of range
# 가져오기에러 201번째 list index out of range
# 가져오기에러 203번째 list index out of range
# 가져오기에러 217번째 list index out of range
# 가져오기에러 218번째 list index out of range
# 가져오기에러 219번째 list index out of range
# 가져오기에러 220번째 list index out of range
# 가져오기에러 258번째 list index out of range
# 가져오기에러 274번째 list index out of range
# 가져오기에러 278번째 list index out of range
# 가져오기에러 279번째 list index out of range
# 가져오기에러 281번째 list index out of range
# 가져오기에러 283번째 list index out of range
# 가져오기에러 285번째 list index out of range
# 가져오기에러 286번째 list index out of range
# 가져오기에러 287번째 list index out of range
# 가져오기에러 293번째 list index out of range
# 가져오기에러 305번째 list index out of range
# 가져오기에러 308번째 list index out of range
# 가져오기에러 311번째 list index out of range
# 가져오기에러 312번째 list index out of range
# 가져오기에러 314번째 list index out of range
# 가져오기에러 315번째 list index out of range
# 가져오기에러 316번째 list index out of range
# 가져오기에러 317번째 list index out of range
# 가져오기에러 318번째 list index out of range
# 가져오기에러 319번째 list index out of range
# 가져오기에러 320번째 list index out of range
# 가져오기에러 321번째 list index out of range
# 가져오기에러 324번째 list index out of range
# 가져오기에러 331번째 list index out of range
# 가져오기에러 335번째 list index out of range
# 가져오기에러 338번째 list index out of range
# 가져오기에러 345번째 list index out of range
# 가져오기에러 346번째 list index out of range
# 가져오기에러 347번째 list index out of range
# 가져오기에러 351번째 list index out of range
# 가져오기에러 354번째 list index out of range
# 가져오기에러 356번째 list index out of range
# 가져오기에러 365번째 list index out of range
# 가져오기에러 383번째 list index out of range
# 가져오기에러 384번째 list index out of range
# 가져오기에러 389번째 HTTPSConnectionPool(host='www.iamhy.com', port=443): Max retries exceeded with url: /212 (Caused by SSLError(CertificateError("hostname 'www.iamhy.com' doesn't match either of '*.tistory.com', 'tistory.com'",),))
# 가져오기에러 393번째 list index out of range
# 가져오기에러 405번째 list index out of range
# 가져오기에러 407번째 list index out of range
# 가져오기에러 408번째 list index out of range
# 가져오기에러 410번째 list index out of range
# 가져오기에러 415번째 list index out of range
# 가져오기에러 420번째 list index out of range
# 가져오기에러 424번째 list index out of range
# 가져오기에러 425번째 list index out of range
# 가져오기에러 429번째 list index out of range
# 가져오기에러 430번째 list index out of range
# 가져오기에러 432번째 list index out of range
# 가져오기에러 433번째 list index out of range
# 가져오기에러 434번째 list index out of range
# 가져오기에러 435번째 list index out of range
# 가져오기에러 436번째 list index out of range
# 가져오기에러 437번째 list index out of range
# 가져오기에러 438번째 list index out of range
# 가져오기에러 441번째 list index out of range
# 가져오기에러 442번째 list index out of range
# 가져오기에러 443번째 list index out of range
# 가져오기에러 445번째 list index out of range
# 가져오기에러 448번째 list index out of range
# 가져오기에러 451번째 list index out of range
# 가져오기에러 452번째 list index out of range
# 가져오기에러 453번째 list index out of range
# 가져오기에러 455번째 list index out of range
# 가져오기에러 457번째 list index out of range
# 가져오기에러 465번째 list index out of range
# 가져오기에러 467번째 list index out of range
# 가져오기에러 468번째 list index out of range
# 가져오기에러 472번째 list index out of range
# 가져오기에러 474번째 list index out of range
# 가져오기에러 480번째 list index out of range
# 가져오기에러 481번째 list index out of range
# 가져오기에러 492번째 list index out of range
# 가져오기에러 493번째 list index out of range
# 가져오기에러 494번째 list index out of range
# 가져오기에러 501번째 list index out of range
# 가져오기에러 502번째 list index out of range
# 가져오기에러 508번째 list index out of range
# 가져오기에러 510번째 list index out of range
# 가져오기에러 511번째 list index out of range
# 가져오기에러 515번째 list index out of range
# 가져오기에러 520번째 list index out of range
# 가져오기에러 521번째 list index out of range
# 가져오기에러 537번째 list index out of range
# 가져오기에러 550번째 list index out of range
# 가져오기에러 571번째 list index out of range
# 가져오기에러 583번째 list index out of range
# 가져오기에러 596번째 list index out of range
# 가져오기에러 598번째 list index out of range
# 가져오기에러 613번째 list index out of range
# 가져오기에러 621번째 list index out of range
# 가져오기에러 623번째 list index out of range
# 가져오기에러 624번째 list index out of range
# 가져오기에러 625번째 list index out of range
# 가져오기에러 626번째 list index out of range
# 가져오기에러 634번째 list index out of range
# 가져오기에러 635번째 list index out of range
# 가져오기에러 636번째 list index out of range
# 가져오기에러 638번째 list index out of range
# 가져오기에러 647번째 list index out of range
# 가져오기에러 648번째 list index out of range
# 가져오기에러 649번째 list index out of range
# 가져오기에러 655번째 list index out of range
# 가져오기에러 679번째 list index out of range
# 가져오기에러 704번째 list index out of range
# 가져오기에러 705번째 list index out of range
# 가져오기에러 706번째 list index out of range
# 가져오기에러 707번째 list index out of range
# 가져오기에러 708번째 list index out of range
# 가져오기에러 709번째 list index out of range
# 가져오기에러 711번째 list index out of range
# 가져오기에러 712번째 list index out of range
# 가져오기에러 714번째 list index out of range
# 가져오기에러 718번째 list index out of range
# 가져오기에러 719번째 list index out of range
# 가져오기에러 720번째 list index out of range
# 가져오기에러 726번째 list index out of range
# 가져오기에러 729번째 list index out of range
# 가져오기에러 751번째 list index out of range
# 가져오기에러 752번째 list index out of range
# 가져오기에러 765번째 list index out of range
# 가져오기에러 769번째 list index out of range
# 가져오기에러 779번째 list index out of range
# 가져오기에러 783번째 list index out of range
# 가져오기에러 787번째 list index out of range
# 가져오기에러 792번째 list index out of range
# 가져오기에러 793번째 list index out of range
# 가져오기에러 796번째 list index out of range
# 가져오기에러 802번째 list index out of range
# 가져오기에러 803번째 list index out of range
# 가져오기에러 807번째 list index out of range
# 가져오기에러 809번째 list index out of range
# 가져오기에러 811번째 list index out of range
# 가져오기에러 813번째 list index out of range
# 가져오기에러 816번째 list index out of range
# 가져오기에러 817번째 list index out of range
# 가져오기에러 819번째 list index out of range
# 가져오기에러 829번째 list index out of range
# 가져오기에러 833번째 list index out of range
# 가져오기에러 835번째 list index out of range
# 가져오기에러 871번째 list index out of range
# 가져오기에러 881번째 list index out of range
# 가져오기에러 893번째 list index out of range
# 가져오기에러 898번째 list index out of range
#
# 검색된길이: 1000
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 8번째 list index out of range
# 가져오기에러 13번째 list index out of range
# 가져오기에러 27번째 list index out of range
# 가져오기에러 28번째 list index out of range
# 가져오기에러 29번째 list index out of range
# 가져오기에러 31번째 list index out of range
# 가져오기에러 33번째 list index out of range
# 가져오기에러 42번째 list index out of range
# 가져오기에러 65번째 list index out of range
# 가져오기에러 83번째 list index out of range
# 가져오기에러 92번째 list index out of range
# 가져오기에러 95번째 list index out of range
# 가져오기에러 105번째 list index out of range
# 가져오기에러 112번째 list index out of range
# 가져오기에러 125번째 list index out of range
# 가져오기에러 126번째 list index out of range
# 가져오기에러 129번째 list index out of range
# 가져오기에러 142번째 list index out of range
# 가져오기에러 143번째 list index out of range
# 가져오기에러 147번째 list index out of range
# 가져오기에러 148번째 list index out of range
# 가져오기에러 150번째 list index out of range
# 가져오기에러 157번째 list index out of range
# 가져오기에러 161번째 list index out of range
# 가져오기에러 163번째 list index out of range
# 가져오기에러 171번째 list index out of range
# 가져오기에러 173번째 list index out of range
# 가져오기에러 250번째 list index out of range
# 가져오기에러 263번째 list index out of range
# 가져오기에러 264번째 list index out of range
# 가져오기에러 268번째 list index out of range
# 가져오기에러 270번째 list index out of range
# 가져오기에러 272번째 list index out of range
# 가져오기에러 282번째 list index out of range
# 가져오기에러 283번째 list index out of range
# 가져오기에러 289번째 list index out of range
# 가져오기에러 295번째 list index out of range
# 가져오기에러 297번째 list index out of range
# 가져오기에러 301번째 list index out of range
# 가져오기에러 308번째 list index out of range
# 가져오기에러 314번째 list index out of range
# 가져오기에러 315번째 list index out of range
# 가져오기에러 323번째 list index out of range
# 가져오기에러 337번째 list index out of range
# 가져오기에러 342번째 list index out of range
# 가져오기에러 351번째 list index out of range
# 가져오기에러 358번째 list index out of range
# 가져오기에러 365번째 list index out of range
# 가져오기에러 373번째 list index out of range
# 가져오기에러 375번째 list index out of range
# 가져오기에러 383번째 list index out of range
# 가져오기에러 384번째 list index out of range
# 가져오기에러 395번째 list index out of range
# 가져오기에러 396번째 list index out of range
# 가져오기에러 400번째 list index out of range
# 가져오기에러 402번째 list index out of range
# 가져오기에러 403번째 list index out of range
# 가져오기에러 406번째 list index out of range
# 가져오기에러 409번째 list index out of range
# 가져오기에러 410번째 list index out of range
# 가져오기에러 419번째 list index out of range
# 가져오기에러 420번째 list index out of range
# 가져오기에러 425번째 list index out of range
# 가져오기에러 427번째 list index out of range
# 가져오기에러 430번째 list index out of range
# 가져오기에러 431번째 list index out of range
# 가져오기에러 433번째 list index out of range
# 가져오기에러 434번째 list index out of range
# 가져오기에러 435번째 list index out of range
# 가져오기에러 441번째 list index out of range
# 가져오기에러 444번째 list index out of range
# 가져오기에러 445번째 list index out of range
# 가져오기에러 452번째 list index out of range
# 가져오기에러 454번째 list index out of range
# 가져오기에러 461번째 list index out of range
# 가져오기에러 463번째 list index out of range
# 가져오기에러 465번째 list index out of range
# 가져오기에러 467번째 list index out of range
# 가져오기에러 476번째 list index out of range
# 가져오기에러 477번째 list index out of range
# 가져오기에러 483번째 list index out of range
# 가져오기에러 502번째 list index out of range
# 가져오기에러 513번째 list index out of range
# 가져오기에러 546번째 HTTPSConnectionPool(host='contentskorea.or.kr', port=443): Max retries exceeded with url: /2728 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D61961E160>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다',))
# 가져오기에러 565번째 list index out of range
# 가져오기에러 567번째 list index out of range
# 가져오기에러 568번째 list index out of range
# 가져오기에러 570번째 list index out of range
# 가져오기에러 581번째 list index out of range
# 가져오기에러 605번째 list index out of range
# 가져오기에러 606번째 list index out of range
# 가져오기에러 651번째 list index out of range
# 가져오기에러 652번째 list index out of range
# 가져오기에러 653번째 list index out of range
# 가져오기에러 654번째 list index out of range
# 가져오기에러 664번째 list index out of range
# 가져오기에러 678번째 list index out of range
# 가져오기에러 679번째 list index out of range
# 가져오기에러 680번째 list index out of range
# 가져오기에러 681번째 list index out of range
# 가져오기에러 682번째 list index out of range
# 가져오기에러 703번째 list index out of range
# 가져오기에러 706번째 list index out of range
# 가져오기에러 712번째 list index out of range
# 가져오기에러 716번째 list index out of range
# 가져오기에러 724번째 list index out of range
# 가져오기에러 738번째 list index out of range
# 가져오기에러 742번째 list index out of range
# 가져오기에러 745번째 list index out of range
# 가져오기에러 747번째 list index out of range
# 가져오기에러 749번째 list index out of range
# 가져오기에러 753번째 HTTPConnectionPool(host='xxxaquaxxx.com', port=80): Max retries exceeded with url: /70091028123 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001D61E4AE198>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
# 가져오기에러 755번째 list index out of range
# 가져오기에러 756번째 list index out of range
# 가져오기에러 761번째 list index out of range
# 가져오기에러 766번째 list index out of range
# 가져오기에러 780번째 list index out of range
# 가져오기에러 784번째 list index out of range
# 가져오기에러 792번째 list index out of range
# 가져오기에러 793번째 list index out of range
# 가져오기에러 801번째 list index out of range
# 가져오기에러 803번째 list index out of range
# 가져오기에러 815번째 list index out of range
# 가져오기에러 818번째 list index out of range
# 가져오기에러 829번째 list index out of range
# 가져오기에러 847번째 list index out of range
# 가져오기에러 857번째 list index out of range
# 가져오기에러 865번째 list index out of range
# 가져오기에러 867번째 list index out of range
# 가져오기에러 868번째 list index out of range
# 가져오기에러 873번째 list index out of range
# 가져오기에러 876번째 list index out of range
# 가져오기에러 878번째 list index out of range
# 가져오기에러 901번째 list index out of range
# 가져오기에러 915번째 list index out of range
# 가져오기에러 922번째 list index out of range
# 가져오기에러 933번째 list index out of range
# 가져오기에러 945번째 list index out of range
# 가져오기에러 953번째 list index out of range
# 가져오기에러 960번째 list index out of range
# 가져오기에러 966번째 list index out of range
# 가져오기에러 973번째 list index out of range
# 가져오기에러 978번째 list index out of range
# 가져오기에러 987번째 list index out of range
# 가져오기에러 988번째 list index out of range
# 가져오기에러 999번째 list index out of range
#
# 검색된길이: 1000
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 22번째 list index out of range
# 가져오기에러 24번째 list index out of range
# 가져오기에러 31번째 list index out of range
# 가져오기에러 32번째 list index out of range
# 가져오기에러 57번째 list index out of range
# 가져오기에러 66번째 list index out of range
# 가져오기에러 68번째 list index out of range
# 가져오기에러 70번째 list index out of range
# 가져오기에러 73번째 list index out of range
# 가져오기에러 85번째 list index out of range
# 가져오기에러 128번째 list index out of range
# 가져오기에러 129번째 list index out of range
# 가져오기에러 131번째 list index out of range
# 가져오기에러 132번째 list index out of range
# 가져오기에러 133번째 list index out of range
# 가져오기에러 141번째 list index out of range
# 가져오기에러 143번째 list index out of range
# 가져오기에러 144번째 list index out of range
# 가져오기에러 145번째 list index out of range
# 가져오기에러 150번째 list index out of range
# 가져오기에러 153번째 list index out of range
# 가져오기에러 156번째 list index out of range
# 가져오기에러 161번째 list index out of range
# 가져오기에러 166번째 list index out of range
# 가져오기에러 168번째 list index out of range
# 가져오기에러 177번째 list index out of range
# 가져오기에러 211번째 list index out of range
# 가져오기에러 214번째 list index out of range
# 가져오기에러 218번째 list index out of range
# 가져오기에러 224번째 list index out of range
# 가져오기에러 226번째 list index out of range
# 가져오기에러 269번째 list index out of range
# 가져오기에러 270번째 list index out of range
# 가져오기에러 278번째 list index out of range
# 가져오기에러 279번째 list index out of range
# 가져오기에러 280번째 list index out of range
# 가져오기에러 288번째 list index out of range
# 가져오기에러 295번째 list index out of range
# 가져오기에러 296번째 list index out of range
# 가져오기에러 300번째 list index out of range
# 가져오기에러 307번째 list index out of range
# 가져오기에러 310번째 list index out of range
# 가져오기에러 313번째 list index out of range
# 가져오기에러 317번째 list index out of range
# 가져오기에러 324번째 list index out of range
# 가져오기에러 330번째 list index out of range
# 가져오기에러 336번째 list index out of range
# 가져오기에러 338번째 list index out of range
# 가져오기에러 341번째 list index out of range
# 가져오기에러 350번째 list index out of range
# 가져오기에러 352번째 list index out of range
# 가져오기에러 361번째 list index out of range
# 가져오기에러 365번째 list index out of range
# 가져오기에러 369번째 list index out of range
# 가져오기에러 376번째 list index out of range
# 가져오기에러 377번째 list index out of range
# 가져오기에러 380번째 list index out of range
# 가져오기에러 391번째 list index out of range
# 가져오기에러 392번째 list index out of range
# 가져오기에러 396번째 list index out of range
# 가져오기에러 403번째 list index out of range
# 가져오기에러 406번째 list index out of range
# 가져오기에러 407번째 list index out of range
# 가져오기에러 415번째 list index out of range
# 가져오기에러 421번째 list index out of range
# 가져오기에러 423번째 list index out of range
# 가져오기에러 429번째 HTTPSConnectionPool(host='contentskorea.or.kr', port=443): Max retries exceeded with url: /3323?category=321228 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D618BD2E48>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다',))
# 가져오기에러 432번째 list index out of range
# 가져오기에러 434번째 list index out of range
# 가져오기에러 436번째 list index out of range
# 가져오기에러 437번째 list index out of range
# 가져오기에러 440번째 list index out of range
# 가져오기에러 446번째 list index out of range
# 가져오기에러 448번째 list index out of range
# 가져오기에러 449번째 list index out of range
# 가져오기에러 450번째 list index out of range
# 가져오기에러 452번째 list index out of range
# 가져오기에러 453번째 list index out of range
# 가져오기에러 455번째 list index out of range
# 가져오기에러 456번째 list index out of range
# 가져오기에러 457번째 list index out of range
# 가져오기에러 468번째 list index out of range
# 가져오기에러 469번째 list index out of range
# 가져오기에러 472번째 list index out of range
# 가져오기에러 488번째 list index out of range
# 가져오기에러 490번째 list index out of range
# 가져오기에러 513번째 list index out of range
# 가져오기에러 530번째 list index out of range
# 가져오기에러 534번째 list index out of range
# 가져오기에러 547번째 list index out of range
# 가져오기에러 570번째 list index out of range
# 가져오기에러 575번째 list index out of range
# 가져오기에러 580번째 list index out of range
# 가져오기에러 587번째 list index out of range
# 가져오기에러 592번째 list index out of range
# 가져오기에러 593번째 list index out of range
# 가져오기에러 594번째 list index out of range
# 가져오기에러 597번째 list index out of range
# 가져오기에러 602번째 list index out of range
# 가져오기에러 603번째 list index out of range
# 가져오기에러 604번째 list index out of range
# 가져오기에러 605번째 list index out of range
# 가져오기에러 606번째 list index out of range
# 가져오기에러 607번째 list index out of range
# 가져오기에러 609번째 list index out of range
# 가져오기에러 610번째 list index out of range
# 가져오기에러 611번째 list index out of range
# 가져오기에러 666번째 list index out of range
# 가져오기에러 717번째 list index out of range
# 가져오기에러 727번째 list index out of range
# 가져오기에러 728번째 list index out of range
# 가져오기에러 753번째 list index out of range
# 가져오기에러 762번째 list index out of range
# 가져오기에러 768번째 list index out of range
# 가져오기에러 776번째 list index out of range
# 가져오기에러 783번째 list index out of range
# 가져오기에러 814번째 list index out of range
# 가져오기에러 815번째 list index out of range
# 가져오기에러 820번째 list index out of range
# 가져오기에러 822번째 list index out of range
# 가져오기에러 824번째 list index out of range
# 가져오기에러 826번째 list index out of range
# 가져오기에러 828번째 list index out of range
# 가져오기에러 830번째 list index out of range
# 가져오기에러 831번째 list index out of range
# 가져오기에러 842번째 list index out of range
# 가져오기에러 845번째 list index out of range
# 가져오기에러 850번째 list index out of range
# 가져오기에러 851번째 list index out of range
# 가져오기에러 864번째 list index out of range
# 가져오기에러 878번째 list index out of range
# 가져오기에러 886번째 list index out of range
# 가져오기에러 887번째 list index out of range
# 가져오기에러 891번째 list index out of range
# 가져오기에러 898번째 list index out of range
# 가져오기에러 901번째 list index out of range
# 가져오기에러 904번째 list index out of range
# 가져오기에러 908번째 list index out of range
# 가져오기에러 921번째 list index out of range
# 가져오기에러 922번째 list index out of range
# 가져오기에러 924번째 list index out of range
# 가져오기에러 927번째 list index out of range
# 가져오기에러 932번째 list index out of range
# 가져오기에러 935번째 list index out of range
# 가져오기에러 941번째 list index out of range
# 가져오기에러 945번째 list index out of range
# 가져오기에러 959번째 list index out of range
# 가져오기에러 962번째 list index out of range
# 가져오기에러 971번째 list index out of range
# 가져오기에러 975번째 list index out of range
# 가져오기에러 984번째 list index out of range
# 가져오기에러 997번째 list index out of range

# %% [markdown]
# ### 각 블로그 들어가서 url주소 따오는 방법(느림)

# %%
options = Options()
# 크롬드라이버 작동 
# os.chdir(',') #크롬드라이버위치
options.add_argument('--start-maximized') #전체화면
# options.add_argument('--headless') #headless(화면안켜고)
driver = webdriver.Chrome(executable_path='./chromedriver', chrome_options=options)

#저장위치
blog_urls = dict()
blog_urls['dates'] = []
blog_urls['title'] = []
blog_urls['urls'] = []

#검색위치 
driver.get(base_url)
#최대 1천개
try :
    for i in tqdm_notebook(range(1,1001)):
        blog_url = driver.find_element_by_xpath(f'//*[@id="sp_blog_{i}"]/div/a[2]')
        #title
        title = blog_url.text
        blog_urls['title'].append(title)
        #date
        date = driver.find_element_by_xpath(f'//*[@id="sp_blog_{i}"]/div/div[1]/span/span/span[1]/span').text
        blog_urls['dates'].append(date)
        blog_url.click()
        driver.switch_to.window(driver.window_handles[-1]) #탭전환
        blog_urls['urls'].append(driver.current_url)
        driver.close()
        driver.switch_to.window(driver.window_handles[0]) #탭복구
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
except:
    pass
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=59999.0), HTML(value='')))

# %% [markdown]
# ### 셀레니움으로 최대치(1천건)까지 아래로 스크롤 후 긁어오기
# * 최대 1천이 아닐때 에러날것 -> 대안1 최대 1천건 스크롤(42번) 문제사항(문서가 짧으면 무의미한 스크롤) 대안필요

# %%
options = Options()
# 크롬드라이버 작동 
options.add_argument('--start-maximized') #전체화면
# options.add_argument('--headless') #headless(화면안켜고)
driver = webdriver.Chrome(executable_path='./chromedriver', chrome_options=options)

#저장위치
blog_urls = dict()
blog_urls['dates'] = []
blog_urls['title'] = []
blog_urls['urls'] = []

#검색위치 
driver.get(base_url)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """

# %%
#_view_review_body_html > div > more-contents > div > ul

# %%
options = Options()
# 크롬드라이버 작동 
options.add_argument('--start-maximized') #전체화면
# options.add_argument('--headless') #headless(화면안켜고)
driver = webdriver.Chrome(executable_path='./chromedriver', chrome_options=options)

#저장위치
blog_urls = dict()
blog_urls['dates'] = []
blog_urls['title'] = []
blog_urls['urls'] = []

#검색위치 
driver.get(base_url)

#최대 아래로 스크롤
count =1
string = '1'
some_tag = '1'
while type(some_tag) == type(string): #sele
    try : 
        some_tag = driver.find_element_by_id('sp_blog_1000')
    except:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        count += 1
print(count)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """
# 34

# %%
options = Options()
# 크롬드라이버 작동 
options.add_argument('--start-maximized') #전체화면
options.add_argument('--headless') #headless(화면안켜고)
driver = webdriver.Chrome(executable_path='./chromedriver', chrome_options=options)

#저장위치
blog_urls = dict()
blog_urls['dates'] = []
blog_urls['title'] = []
blog_urls['urls'] = []

#검색위치 
driver.get(base_url)

#최대 아래로 스크롤
count =1
string = '1'
some_tag = '1'
for i in range(0,40):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(0.1)
    count += 1
source = driver.page_source
# print(count)
driver.close()

#각 정보 불러오기
soup = BeautifulSoup(source, 'html.parser')

#dates
dates_list = soup.select('div > div.total_sub > span > span > span.etc_dsc_area > span')
dates = pd.Series(dates_list).apply(lambda x : x.text)
blog_urls['dates'] = blog_urls['dates'] + list(dates)

#titles
title_list = soup.select('div > a.api_txt_lines.total_tit')
titles = pd.Series(title_list).apply(lambda x : x.text)
blog_urls['title'] = blog_urls['title'] + list(titles)

#link
link_list = soup.select('div.total_dsc_wrap a.total_dsc')
links = pd.Series(link_list).apply(lambda x : x.get('href'))
blog_urls['urls'] = blog_urls['urls'] + list(links)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """

# %%
df = pd.DataFrame(blog_urls)

df_dict =  df.to_dict()

# %%
pd.DataFrame(df_dict)
# Out:
#           dates                          title  \
# 0   2020.12.17.               드라이브로 강릉 가볼만한곳 6
# 1   2020.12.25.           강릉 가볼만한곳 정동진부터 당일 5곳
# 2   2020.12.29.                 신선하게 즐겼던 강릉 횟집
# 3   2020.12.31.            엄선해본 강원도 강릉 맛집 LIST
# 4   2020.12.29.             다채로웠던 강릉 맛집 추천 리스트
# 5   2020.12.26.          광고가 아닌 강릉 횟집 경포대 환호횟집
# 6   2020.12.26.                   단번에 빠졌던 강릉횟집
# 7   2020.12.26.                     행복했던 강릉 횟집
# 8   2020.11.28.                겨울에 강릉 가볼만한곳 모음
# 9   2020.12.25.                강릉 회센터 회 맛집이구만!
# 10  2020.12.21.                     가치있는 강릉 횟집
# 11  2020.12.25.            싱싱했던 강릉 포장 맛집 list5
# 12  2020.12.31.                 마음갔던 강릉 맛집 리스트
# 13  2020.12.30.                     강렬했던 강릉 횟집
# 14  2020.12.22.     강릉 생선구이 맛집 / 등대수산 주문진항 근처!
# 15  2020.12.17.                  찐이었던 강릉안목해변맛집
# 16  2020.12.18.                 강릉 시내 맛집 흡족스러워
# 17  2020.12.15.            예술적인 강릉 대방어 회포장 총정리
# 18  2020.12.31.               기쁨 주는 강릉 맛집 LIST
# 19  2020.12.26.                 넘사벽이었던 강릉맛집 모음
# 20  2020.12.26.                 맛과 정성의 강릉맛집 모음
# 21  2020.12.26.  강릉 중앙시장 먹거리 주차장 월화거리 꼼꼼히 둘러보기
# 22  2020.12.18.             감탄했던 강릉 중앙시장 맛집 모음
# 23  2020.12.30.               호화스러운 강릉 강문해변 맛집
# 24  2020.12.29.      생생정보에 나온 강릉 조개구이 무한리필 어디?
# 25  2020.12.23.               자랑하고싶던 강릉 맛집 리스트
# 26  2020.12.30.           마음에 들었던 강릉 주문진 맛집 모음
# 27  2020.12.20.                    최고였던 강릉 먹거리
# 28  2020.12.24.            계속 가고 싶은 강릉역 맛집 리스트
# 29  2020.12.30.                  강릉 통일공원 함정전시관
#
#                                                  urls
# 0   https://blog.naver.com/nailstan?Redirect=Log&l...
# 1   https://blog.naver.com/tcacyc?Redirect=Log&log...
# 2               https://dlfauddl.blog.me/222189422030
# 3   https://blog.naver.com/opop525?Redirect=Log&lo...
# 4   https://blog.naver.com/hangilchi?Redirect=Log&...
# 5   https://blog.naver.com/river0703?Redirect=Log&...
# 6   https://blog.naver.com/llzzinll?Redirect=Log&l...
# 7   https://blog.naver.com/amanda_som?Redirect=Log...
# 8   https://blog.naver.com/ultrabat?Redirect=Log&l...
# 9   https://blog.naver.com/amore_bh?Redirect=Log&l...
# 10            https://hoi1004226.blog.me/222180665442
# 11  https://blog.naver.com/meeae80?Redirect=Log&lo...
# 12              https://arum0825.blog.me/222190877799
# 13  https://blog.naver.com/voyage_iny?Redirect=Log...
# 14  https://blog.naver.com/jjubi77?Redirect=Log&lo...
# 15  https://blog.naver.com/hai33?Redirect=Log&logN...
# 16  https://blog.naver.com/sosotaya2?Redirect=Log&...
# 17  https://blog.naver.com/hogengggy?Redirect=Log&...
# 18              https://horong95.blog.me/222191202147
# 19  https://blog.naver.com/asdffggg2?Redirect=Log&...
# 20  https://blog.naver.com/candypowder?Redirect=Lo...
# 21  https://blog.naver.com/ultrabat?Redirect=Log&l...
# 22  https://blog.naver.com/zzanguna?Redirect=Log&l...
# 23  https://blog.naver.com/noola0728?Redirect=Log&...
# 24  https://blog.naver.com/friday77?Redirect=Log&l...
# 25  https://blog.naver.com/jisunny1215?Redirect=Lo...
# 26  https://blog.naver.com/ozoz1128?Redirect=Log&l...
# 27  https://blog.naver.com/corea_hyun?Redirect=Log...
# 28  https://blog.naver.com/selee0000?Redirect=Log&...
# 29  https://blog.naver.com/han4869?Redirect=Log&lo...

# %% [markdown]
# ### 저장

# %%
# 본문가져오기
output_error = []
texts = []
for i, url in tqdm_notebook(enumerate(blog_urls['urls'])):
    count = i
    try:
        # 블로그 url안에 들어가기(아직 크롤링불가)
        get_blog_post_content_code = requests.get(url)
        get_blog_post_content_text = get_blog_post_content_code.text
        get_blog_post_content_soup = BeautifulSoup(
            get_blog_post_content_text, 'lxml')

        # 크롤링가능한 url에 접속
        real_blog_post_url = "http://blog.naver.com" + get_blog_post_content_soup.select('#mainFrame')[0].get('src')
        get_real_blog_post_content_code = requests.get(real_blog_post_url)
        get_real_blog_post_content_text = get_real_blog_post_content_code.text
        get_real_blog_post_content_soup = BeautifulSoup(get_real_blog_post_content_text, 'lxml')

        # 본문  (postviewarea 패턴과 se-main-container 2가지 유형이 있어 분리함)
        try:
            blog_post_content = get_real_blog_post_content_soup.select('div.se-main-container')
            if len(blog_post_content) == 0:
                blog_post_content = get_real_blog_post_content_soup.select('div#postViewArea')
                if len(blog_post_content) == 0:
                    blog_post_content = get_real_blog_post_content_soup.select('div.se_component_wrap.sect_dsc.__se_component_area')

            string = ""
            for sentence in blog_post_content[0].stripped_strings:
                try :
                    string += " "+sentence.replace('\xa0', " ")
                except :
                    pass
                # 비언어 텍스트제거
            string = del_outword(string)
            # 공백에러대처
            blank_check = string.replace(" ", "")
            if len(blank_check) == 0:
                texts.append(["X"])
            else:
                texts.append([string])
            count += 1
        except Exception as ex:
            print('url_load_error')
            texts.append(["X"])
            output_error.append(count)
            count += 1

    except Exception as ex:
        print('가져오기에러 {num}번째'.format(num=count), ex)
        output_error.append(count)
        count += 1
        pass
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 가져오기에러 73번째 list index out of range
# 가져오기에러 93번째 list index out of range
# 가져오기에러 98번째 list index out of range
# 가져오기에러 99번째 list index out of range
# 가져오기에러 221번째 list index out of range
# 가져오기에러 235번째 list index out of range
# 가져오기에러 245번째 list index out of range
# 가져오기에러 259번째 list index out of range
# 가져오기에러 284번째 list index out of range
# 가져오기에러 314번째 list index out of range
# 가져오기에러 325번째 list index out of range
# 가져오기에러 336번째 list index out of range
# 가져오기에러 337번째 list index out of range
# 가져오기에러 358번째 list index out of range
# 가져오기에러 359번째 list index out of range
# 가져오기에러 419번째 list index out of range
# 가져오기에러 471번째 list index out of range
# 가져오기에러 480번째 list index out of range
# 가져오기에러 493번째 list index out of range
# 가져오기에러 518번째 list index out of range
# 가져오기에러 602번째 list index out of range
# 가져오기에러 628번째 list index out of range

# %%
len(blog_urls['dates'])
# Out:
# 630

# %%
len(output_error)
# Out:
# 22

# %%
len(texts)
# Out:
# 608

# %%
#후처리 및 dataframe 생성
df = pd.DataFrame(blog_urls)
df = df.drop(output_error)
df['text'] = texts
lenght = df.shape[0]

#저장
if save == True:
    today = datetime.datetime.today().date()
    str(today)
    os.makedirs(f'./new_output/{keyword}',exist_ok=True)
    df.to_csv(f'./new_output/{keyword}/{date_from}~{date_to}_{keyword}_{lenght}_{today}.csv',index=False)
